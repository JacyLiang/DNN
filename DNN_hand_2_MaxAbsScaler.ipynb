# %%
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.model_selection import train_test_split

# %%
#載入資料
df = pd.read_csv('./output4.csv', encoding='utf-8')
df
# Out:
#        class  thumb_CmcX  thumb_CmcY  thumb_CmcZ  thumb_McpX  thumb_McpY  \
# 0          0    0.013346   -0.078824   -0.093423    0.031121   -0.122133
# 1          0    0.027224   -0.044876   -0.043898    0.058716   -0.081201
# 2          0   -0.003453    0.058013   -0.038275    0.007701    0.082564
# 3          0    0.011858   -0.065664   -0.090578    0.034992   -0.107807
# 4          0    0.024853   -0.048601   -0.048028    0.050411   -0.086527
# ...      ...         ...         ...         ...         ...         ...
# 35170      4    0.092155   -0.072534   -0.064873    0.224030   -0.116162
# 35171      4    0.092424   -0.073813   -0.064069    0.225228   -0.118873
# 35172      4    0.097000   -0.064246   -0.076335    0.230042   -0.105550
# 35173      4    0.100859   -0.063578   -0.075059    0.233116   -0.103082
# 35174      4    0.098224   -0.066448   -0.072397    0.233586   -0.104373
#
#        thumb_McpZ  thumb_IpX  thumb_IpY  thumb_IpZ  ...  pinky_McpZ  \
# 0       -0.160828   0.008913  -0.113420  -0.211022  ...   -0.146264
# 1       -0.078251   0.055767  -0.074666  -0.108053  ...   -0.089761
# 2       -0.066121   0.003853   0.067236  -0.087953  ...   -0.064716
# 3       -0.156370   0.007863  -0.092267  -0.208585  ...   -0.136011
# 4       -0.089649   0.039719  -0.073551  -0.126198  ...   -0.110127
# ...           ...        ...        ...        ...  ...         ...
# 35170   -0.068147   0.343033  -0.115294  -0.065577  ...    0.088988
# 35171   -0.067604   0.344341  -0.116408  -0.065691  ...    0.084817
# 35172   -0.082055   0.348379  -0.105353  -0.079992  ...    0.102595
# 35173   -0.080414   0.350211  -0.102614  -0.078176  ...    0.104006
# 35174   -0.077202   0.350857  -0.101643  -0.075379  ...    0.099498
#
#        pinky_PipX  pinky_PipY  pinky_PipZ  pinky_DipX  pinky_DipY  pinky_DipZ  \
# 0       -0.093332    0.077454   -0.197066   -0.100144    0.039600   -0.197679
# 1       -0.011452    0.085340   -0.123443   -0.016239    0.053635   -0.115443
# 2        0.008161   -0.042829   -0.089203   -0.002254   -0.042870   -0.089281
# 3       -0.061092    0.088679   -0.195662   -0.074918    0.046089   -0.193745
# 4       -0.028435    0.078580   -0.158202   -0.026730    0.049350   -0.147598
# ...           ...         ...         ...         ...         ...         ...
# 35170    0.306037    0.071159    0.065973    0.288056    0.080720    0.044411
# 35171    0.311503    0.071365    0.058307    0.291183    0.078983    0.036301
# 35172    0.317471    0.070517    0.072401    0.308306    0.085774    0.039162
# 35173    0.320064    0.072447    0.077781    0.313789    0.085835    0.045871
# 35174    0.319386    0.074944    0.071577    0.312857    0.088435    0.037308
#
#        pinky_TipX  pinky_TipY  pinky_TipZ
# 0       -0.074212    0.029099   -0.192775
# 1        0.009828    0.048981   -0.101101
# 2        0.021662   -0.038748   -0.085531
# 3       -0.055045    0.027574   -0.181527
# 4        0.008735    0.047540   -0.126619
# ...           ...         ...         ...
# 35170    0.249058    0.089427    0.034287
# 35171    0.249589    0.085530    0.026626
# 35172    0.265045    0.101793    0.021297
# 35173    0.272907    0.100060    0.028143
# 35174    0.268381    0.101102    0.017385
#
# [35175 rows x 61 columns]

# %%
#取標籤
label = df["class"]
label
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 35170    4
# 35171    4
# 35172    4
# 35173    4
# 35174    4
# Name: class, Length: 35175, dtype: int64

# %%
#取出特徵
data = df.iloc[:,1:]
data
# Out:
#        thumb_CmcX  thumb_CmcY  thumb_CmcZ  thumb_McpX  thumb_McpY  thumb_McpZ  \
# 0        0.013346   -0.078824   -0.093423    0.031121   -0.122133   -0.160828
# 1        0.027224   -0.044876   -0.043898    0.058716   -0.081201   -0.078251
# 2       -0.003453    0.058013   -0.038275    0.007701    0.082564   -0.066121
# 3        0.011858   -0.065664   -0.090578    0.034992   -0.107807   -0.156370
# 4        0.024853   -0.048601   -0.048028    0.050411   -0.086527   -0.089649
# ...           ...         ...         ...         ...         ...         ...
# 35170    0.092155   -0.072534   -0.064873    0.224030   -0.116162   -0.068147
# 35171    0.092424   -0.073813   -0.064069    0.225228   -0.118873   -0.067604
# 35172    0.097000   -0.064246   -0.076335    0.230042   -0.105550   -0.082055
# 35173    0.100859   -0.063578   -0.075059    0.233116   -0.103082   -0.080414
# 35174    0.098224   -0.066448   -0.072397    0.233586   -0.104373   -0.077202
#
#        thumb_IpX  thumb_IpY  thumb_IpZ  thumb_TipX  ...  pinky_McpZ  \
# 0       0.008913  -0.113420  -0.211022   -0.008307  ...   -0.146264
# 1       0.055767  -0.074666  -0.108053    0.056937  ...   -0.089761
# 2       0.003853   0.067236  -0.087953   -0.004198  ...   -0.064716
# 3       0.007863  -0.092267  -0.208585   -0.020125  ...   -0.136011
# 4       0.039719  -0.073551  -0.126198    0.039590  ...   -0.110127
# ...          ...        ...        ...         ...  ...         ...
# 35170   0.343033  -0.115294  -0.065577    0.421387  ...    0.088988
# 35171   0.344341  -0.116408  -0.065691    0.422458  ...    0.084817
# 35172   0.348379  -0.105353  -0.079992    0.431348  ...    0.102595
# 35173   0.350211  -0.102614  -0.078176    0.432410  ...    0.104006
# 35174   0.350857  -0.101643  -0.075379    0.432598  ...    0.099498
#
#        pinky_PipX  pinky_PipY  pinky_PipZ  pinky_DipX  pinky_DipY  pinky_DipZ  \
# 0       -0.093332    0.077454   -0.197066   -0.100144    0.039600   -0.197679
# 1       -0.011452    0.085340   -0.123443   -0.016239    0.053635   -0.115443
# 2        0.008161   -0.042829   -0.089203   -0.002254   -0.042870   -0.089281
# 3       -0.061092    0.088679   -0.195662   -0.074918    0.046089   -0.193745
# 4       -0.028435    0.078580   -0.158202   -0.026730    0.049350   -0.147598
# ...           ...         ...         ...         ...         ...         ...
# 35170    0.306037    0.071159    0.065973    0.288056    0.080720    0.044411
# 35171    0.311503    0.071365    0.058307    0.291183    0.078983    0.036301
# 35172    0.317471    0.070517    0.072401    0.308306    0.085774    0.039162
# 35173    0.320064    0.072447    0.077781    0.313789    0.085835    0.045871
# 35174    0.319386    0.074944    0.071577    0.312857    0.088435    0.037308
#
#        pinky_TipX  pinky_TipY  pinky_TipZ
# 0       -0.074212    0.029099   -0.192775
# 1        0.009828    0.048981   -0.101101
# 2        0.021662   -0.038748   -0.085531
# 3       -0.055045    0.027574   -0.181527
# 4        0.008735    0.047540   -0.126619
# ...           ...         ...         ...
# 35170    0.249058    0.089427    0.034287
# 35171    0.249589    0.085530    0.026626
# 35172    0.265045    0.101793    0.021297
# 35173    0.272907    0.100060    0.028143
# 35174    0.268381    0.101102    0.017385
#
# [35175 rows x 60 columns]

# %%
#資料標準化
scaler = MaxAbsScaler()
data = scaler.fit_transform(data)
data
# Out:
# array([[ 0.04577342, -0.32239307, -0.32610282, ..., -0.08840834,
#          0.04825724, -0.42808799],
#        [ 0.09337214, -0.18354407, -0.15322953, ...,  0.01170745,
#          0.08122823, -0.22451109],
#        [-0.01184336,  0.23727552, -0.1336044 , ...,  0.02580523,
#         -0.06425893, -0.18993556],
#        ...,
#        [ 0.3326941 , -0.26276715, -0.26645409, ...,  0.31574565,
#          0.16880958,  0.04729449],
#        [ 0.34593068, -0.26003456, -0.26200157, ...,  0.32511078,
#          0.16593633,  0.06249718],
#        [ 0.33689123, -0.27177379, -0.25270889, ...,  0.31971863,
#          0.16766406,  0.03860568]])

# %%
#分割資料
#把資料轉numpy
reshaped_data = np.array(data)
reshaped_label = np.array(label)
#將資料分為8:2

train_feature, test_feature, train_label, test_label = train_test_split(reshaped_data, reshaped_label, test_size=0.2, random_state = 42)

# split_boundary = int(reshaped_data.shape[0]*0.8)
# train_feature = reshaped_data[: split_boundary]
# test_feature = reshaped_data[split_boundary:]
# train_label = reshaped_label[: split_boundary]
# test_label = reshaped_label[split_boundary:]
print("測試資料:", train_feature)
print("訓練資料:", test_feature)
print("測試資料數量:", len(train_feature))
print("訓練資料數量:", len(test_feature))
print("測試資料維度:", train_feature.shape)
print("訓練資料維度:", test_feature.shape)
# Out:
# 測試資料: [[ 0.23464381 -0.31003122 -0.27231047 ...  0.40907839  0.24674011
#   -0.32617725]
#  [ 0.23946006 -0.29225978 -0.37957844 ...  0.42864791  0.42347843
#   -0.47295121]
#  [ 0.32546982 -0.31384792 -0.2062963  ...  0.27691889  0.14275821
#    0.03418929]
#  ...
#  [ 0.50294926 -0.44706159 -0.82045987 ...  0.44032983  0.17326665
#    0.19316095]
#  [ 0.07914856 -0.5563007  -0.1764816  ...  0.21052219  0.10460522
#   -0.01664912]
#  [ 0.29022024 -0.159972   -0.47966174 ...  0.40951493  0.39889967
#   -0.25896019]]
# 訓練資料: [[ 0.12916061 -0.5745268  -0.19006619 ...  0.21835923  0.10600369
#    0.01159274]
#  [ 0.05929845  0.16601032 -0.04041446 ... -0.04616544  0.01762534
#   -0.01514538]
#  [ 0.0498389   0.44594755 -0.46337237 ...  0.31984232  0.52726745
#   -0.01011496]
#  ...
#  [-0.02472687  0.19882001 -0.11101454 ... -0.00069309  0.35940004
#   -0.13968597]
#  [ 0.17235112 -0.2557415  -0.32784637 ...  0.30402445  0.15854353
#   -0.24229632]
#  [ 0.20823537 -0.66114778 -0.21856257 ...  0.27225711  0.09186465
#   -0.05035317]]
# 測試資料數量: 28140
# 訓練資料數量: 7035
# 測試資料維度: (28140, 60)
# 訓練資料維度: (7035, 60)

# %%
train_label = np_utils.to_categorical(train_label)
test_label= np_utils.to_categorical(test_label)
print("訓練標籤:",train_label.shape)
print("測試標籤:",test_label.shape)
# Out:
# 訓練標籤: (28140, 5)
# 測試標籤: (7035, 5)

# %%
#更改資料維度
train_feature = np.reshape(train_feature, (train_feature.shape[0], train_feature.shape[1], 1))
test_feature = np.reshape(test_feature, (test_feature.shape[0], test_feature.shape[1], 1))
print("測試資料維度:", train_feature.shape)
print("訓練資料維度:", test_feature.shape)
# Out:
# 測試資料維度: (28140, 60, 1)
# 訓練資料維度: (7035, 60, 1)

# %%
#訓練模型
model = Sequential()
n = 0.2
model.add(Dense(units=32, input_dim=60, activation='relu'))    #輸入60個特徵
model.add(Dropout(n))
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(n))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(n))
model.add(Dense(units=256, activation='relu'))
model.add(Dropout(n))
model.add(Dense(units=5, activation='softmax'))   #輸出為5個分類
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                1952
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 256)               33024
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 46,693
# Trainable params: 46,693
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
fitmodel = model.fit(x=train_feature, y=train_label, validation_split=0.2, epochs=40, batch_size=20, verbose=2)
score = model.evaluate(x=test_feature, y=test_label, verbose=2)
print('\n測試資料準確率:', score[1])
# Out:
# Epoch 1/40
# 1126/1126 - 7s - loss: 0.5856 - accuracy: 0.7618 - val_loss: 0.2780 - val_accuracy: 0.8989 - 7s/epoch - 6ms/step
# Epoch 2/40
# 1126/1126 - 6s - loss: 0.2816 - accuracy: 0.8999 - val_loss: 0.1389 - val_accuracy: 0.9517 - 6s/epoch - 5ms/step
# Epoch 3/40
# 1126/1126 - 8s - loss: 0.2105 - accuracy: 0.9261 - val_loss: 0.1100 - val_accuracy: 0.9682 - 8s/epoch - 7ms/step
# Epoch 4/40
# 1126/1126 - 9s - loss: 0.1726 - accuracy: 0.9407 - val_loss: 0.1170 - val_accuracy: 0.9586 - 9s/epoch - 8ms/step
# Epoch 5/40
# 1126/1126 - 9s - loss: 0.1589 - accuracy: 0.9468 - val_loss: 0.0850 - val_accuracy: 0.9767 - 9s/epoch - 8ms/step
# Epoch 6/40
# 1126/1126 - 9s - loss: 0.1489 - accuracy: 0.9515 - val_loss: 0.0837 - val_accuracy: 0.9764 - 9s/epoch - 8ms/step
# Epoch 7/40
# 1126/1126 - 9s - loss: 0.1319 - accuracy: 0.9568 - val_loss: 0.0827 - val_accuracy: 0.9781 - 9s/epoch - 8ms/step
# Epoch 8/40
# 1126/1126 - 9s - loss: 0.1375 - accuracy: 0.9555 - val_loss: 0.0899 - val_accuracy: 0.9732 - 9s/epoch - 8ms/step
# Epoch 9/40
# 1126/1126 - 9s - loss: 0.1210 - accuracy: 0.9601 - val_loss: 0.0686 - val_accuracy: 0.9810 - 9s/epoch - 8ms/step
# Epoch 10/40
# 1126/1126 - 9s - loss: 0.1167 - accuracy: 0.9624 - val_loss: 0.0614 - val_accuracy: 0.9828 - 9s/epoch - 8ms/step
# Epoch 11/40
# 1126/1126 - 9s - loss: 0.1077 - accuracy: 0.9636 - val_loss: 0.0760 - val_accuracy: 0.9757 - 9s/epoch - 8ms/step
# Epoch 12/40
# 1126/1126 - 9s - loss: 0.1157 - accuracy: 0.9610 - val_loss: 0.0562 - val_accuracy: 0.9870 - 9s/epoch - 8ms/step
# Epoch 13/40
# 1126/1126 - 9s - loss: 0.1032 - accuracy: 0.9669 - val_loss: 0.0489 - val_accuracy: 0.9863 - 9s/epoch - 8ms/step
# Epoch 14/40
# 1126/1126 - 9s - loss: 0.1046 - accuracy: 0.9671 - val_loss: 0.0447 - val_accuracy: 0.9865 - 9s/epoch - 8ms/step
# Epoch 15/40
# 1126/1126 - 9s - loss: 0.1007 - accuracy: 0.9680 - val_loss: 0.0486 - val_accuracy: 0.9861 - 9s/epoch - 8ms/step
# Epoch 16/40
# 1126/1126 - 9s - loss: 0.0926 - accuracy: 0.9700 - val_loss: 0.0593 - val_accuracy: 0.9817 - 9s/epoch - 8ms/step
# Epoch 17/40
# 1126/1126 - 9s - loss: 0.1006 - accuracy: 0.9675 - val_loss: 0.0462 - val_accuracy: 0.9890 - 9s/epoch - 8ms/step
# Epoch 18/40
# 1126/1126 - 9s - loss: 0.0962 - accuracy: 0.9682 - val_loss: 0.0464 - val_accuracy: 0.9849 - 9s/epoch - 8ms/step
# Epoch 19/40
# 1126/1126 - 9s - loss: 0.0969 - accuracy: 0.9690 - val_loss: 0.0494 - val_accuracy: 0.9858 - 9s/epoch - 8ms/step
# Epoch 20/40
# 1126/1126 - 9s - loss: 0.0942 - accuracy: 0.9702 - val_loss: 0.0565 - val_accuracy: 0.9808 - 9s/epoch - 8ms/step
# Epoch 21/40
# 1126/1126 - 9s - loss: 0.0943 - accuracy: 0.9699 - val_loss: 0.0474 - val_accuracy: 0.9860 - 9s/epoch - 8ms/step
# Epoch 22/40
# 1126/1126 - 9s - loss: 0.0875 - accuracy: 0.9736 - val_loss: 0.0399 - val_accuracy: 0.9874 - 9s/epoch - 8ms/step
# Epoch 23/40
# 1126/1126 - 9s - loss: 0.0882 - accuracy: 0.9716 - val_loss: 0.0581 - val_accuracy: 0.9808 - 9s/epoch - 8ms/step
# Epoch 24/40
# 1126/1126 - 9s - loss: 0.0867 - accuracy: 0.9731 - val_loss: 0.0404 - val_accuracy: 0.9876 - 9s/epoch - 8ms/step
# Epoch 25/40
# 1126/1126 - 9s - loss: 0.0872 - accuracy: 0.9720 - val_loss: 0.0360 - val_accuracy: 0.9892 - 9s/epoch - 8ms/step
# Epoch 26/40
# 1126/1126 - 9s - loss: 0.0781 - accuracy: 0.9757 - val_loss: 0.0319 - val_accuracy: 0.9890 - 9s/epoch - 8ms/step
# Epoch 27/40
# 1126/1126 - 9s - loss: 0.0752 - accuracy: 0.9760 - val_loss: 0.0423 - val_accuracy: 0.9900 - 9s/epoch - 8ms/step
# Epoch 28/40
# 1126/1126 - 9s - loss: 0.0852 - accuracy: 0.9730 - val_loss: 0.0454 - val_accuracy: 0.9877 - 9s/epoch - 8ms/step
# Epoch 29/40
# 1126/1126 - 9s - loss: 0.0830 - accuracy: 0.9740 - val_loss: 0.0410 - val_accuracy: 0.9888 - 9s/epoch - 8ms/step
# Epoch 30/40
# 1126/1126 - 9s - loss: 0.0786 - accuracy: 0.9754 - val_loss: 0.0391 - val_accuracy: 0.9899 - 9s/epoch - 8ms/step
# Epoch 31/40
# 1126/1126 - 9s - loss: 0.0802 - accuracy: 0.9742 - val_loss: 0.0323 - val_accuracy: 0.9909 - 9s/epoch - 8ms/step
# Epoch 32/40
# 1126/1126 - 9s - loss: 0.0796 - accuracy: 0.9732 - val_loss: 0.0354 - val_accuracy: 0.9908 - 9s/epoch - 8ms/step
# Epoch 33/40
# 1126/1126 - 9s - loss: 0.0761 - accuracy: 0.9753 - val_loss: 0.0367 - val_accuracy: 0.9897 - 9s/epoch - 8ms/step
# Epoch 34/40
# 1126/1126 - 9s - loss: 0.0771 - accuracy: 0.9759 - val_loss: 0.0346 - val_accuracy: 0.9913 - 9s/epoch - 8ms/step
# Epoch 35/40
# 1126/1126 - 9s - loss: 0.0756 - accuracy: 0.9761 - val_loss: 0.0345 - val_accuracy: 0.9904 - 9s/epoch - 8ms/step
# Epoch 36/40
# 1126/1126 - 9s - loss: 0.0757 - accuracy: 0.9764 - val_loss: 0.0379 - val_accuracy: 0.9904 - 9s/epoch - 8ms/step
# Epoch 37/40
# 1126/1126 - 9s - loss: 0.0745 - accuracy: 0.9779 - val_loss: 0.0351 - val_accuracy: 0.9909 - 9s/epoch - 8ms/step
# Epoch 38/40
# 1126/1126 - 9s - loss: 0.0717 - accuracy: 0.9767 - val_loss: 0.0307 - val_accuracy: 0.9920 - 9s/epoch - 8ms/step
# Epoch 39/40
# 1126/1126 - 9s - loss: 0.0697 - accuracy: 0.9788 - val_loss: 0.0400 - val_accuracy: 0.9892 - 9s/epoch - 8ms/step
# Epoch 40/40
# 1126/1126 - 9s - loss: 0.0716 - accuracy: 0.9778 - val_loss: 0.0300 - val_accuracy: 0.9913 - 9s/epoch - 8ms/step
# 220/220 - 1s - loss: 0.0239 - accuracy: 0.9933 - 869ms/epoch - 4ms/step
#
# 測試資料準確率: 0.9933190941810608
