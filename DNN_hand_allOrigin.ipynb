# 67803    0.270327    0.060239   -0.105540    0.223794    0.077103   -0.116620
#
#        pinky_TipX  pinky_TipY  pinky_TipZ
# 0       -0.044463    0.142457   -0.103716
# 1        0.053499    0.083453   -0.070508
# 2        0.006033    0.127925   -0.042074
# 3       -0.059853    0.092084   -0.074993
# 4       -0.068013    0.034524   -0.085842
# ...           ...         ...         ...
# 67799    0.162459    0.076754   -0.126205
# 67800    0.148834    0.086681   -0.124629
# 67801    0.159365    0.081097   -0.128880
# 67802    0.161029    0.083968   -0.121660
# 67803    0.171071    0.079793   -0.111782
#
# [67804 rows x 60 columns]

# %%
#資料標準化
scaler = MinMaxScaler(feature_range=(0,1))
data = scaler.fit_transform(data)
data
# Out:
# array([[0.46457903, 0.39362856, 0.38477537, ..., 0.43479194, 0.56737464,
#         0.46266341],
#        [0.45563931, 0.58927377, 0.41518598, ..., 0.50781681, 0.49988148,
#         0.49738491],
#        [0.49562819, 0.4371641 , 0.42691313, ..., 0.47243402, 0.55075176,
#         0.52711547],
#        ...,
#        [0.48010652, 0.37656782, 0.35557279, ..., 0.58673291, 0.49718664,
#         0.43635204],
#        [0.49585124, 0.37116193, 0.37359055, ..., 0.58797345, 0.50047009,
#         0.4439007 ],
#        [0.49995094, 0.36283737, 0.38462268, ..., 0.59545924, 0.49569457,
#         0.45422963]])

# %%
#分割資料
#把資料轉numpy
reshaped_data = np.array(data)
reshaped_label = np.array(label)

#將資料分為8:2
train_feature, test_feature, train_label, test_label = train_test_split(reshaped_data, reshaped_label, test_size=0.2, random_state = 42)

# split_boundary = int(reshaped_data.shape[0]*0.8)
# train_feature = reshaped_data[: split_boundary]
# test_feature = reshaped_data[split_boundary:]
# train_label = reshaped_label[: split_boundary]
# test_label = reshaped_label[split_boundary:]
print("訓練資料:", train_feature)
print("測試資料:", test_feature)
print("訓練資料數量:", len(train_feature))
print("測試資料數量:", len(test_feature))
print("訓練資料維度:", train_feature.shape)
print("測試資料維度:", test_feature.shape)
# Out:
# 訓練資料: [[0.54566103 0.21337827 0.40272997 ... 0.63628521 0.43516734 0.49671951]
#  [0.63680716 0.37062535 0.31159224 ... 0.79987026 0.55728958 0.50565753]
#  [0.52302383 0.21818047 0.3770666  ... 0.63513922 0.45652825 0.48384773]
#  ...
#  [0.50660237 0.32122133 0.39097512 ... 0.58775343 0.40490925 0.5076494 ]
#  [0.68575969 0.43355607 0.35627276 ... 0.65761792 0.48565171 0.68436813]
#  [0.31465206 0.44823861 0.32598393 ... 0.49372636 0.55572769 0.41907353]]
# 測試資料: [[0.77464778 0.68642032 0.40871374 ... 0.73597174 0.50557424 0.82403886]
#  [0.4253492  0.34172987 0.34126865 ... 0.54829664 0.45926468 0.46067337]
#  [0.46009315 0.34146209 0.35006043 ... 0.63247522 0.53125767 0.40936174]
#  ...
#  [0.60089562 0.43713826 0.27497122 ... 0.58983913 0.4993357  0.55218073]
#  [0.57177451 0.35372286 0.33369181 ... 0.60139093 0.47235676 0.54872777]
#  [0.58223886 0.55266953 0.30574679 ... 0.60046567 0.61895727 0.58737091]]
# 訓練資料數量: 54243
# 測試資料數量: 13561
# 訓練資料維度: (54243, 60)
# 測試資料維度: (13561, 60)

# %%
train_label = np_utils.to_categorical(train_label)
test_label= np_utils.to_categorical(test_label)
print("訓練標籤:",train_label.shape)
print("測試標籤:",test_label.shape)
# Out:
# 訓練標籤: (54243, 5)
# 測試標籤: (13561, 5)

# %%
#更改資料維度
train_feature = np.reshape(train_feature, (train_feature.shape[0], train_feature.shape[1], 1))
test_feature = np.reshape(test_feature, (test_feature.shape[0], test_feature.shape[1], 1))
print("訓練資料維度:", train_feature.shape)
print("測試資料維度:", test_feature.shape)
# Out:
# 訓練資料維度: (54243, 60, 1)
# 測試資料維度: (13561, 60, 1)

# %%
#訓練模型
model = Sequential()
n = 0.2
model.add(Dense(units=32, input_dim=60, activation='relu'))    #輸入60個特徵
model.add(Dropout(n))
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(n))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(n))
model.add(Dense(units=256, activation='relu'))
model.add(Dropout(n))
model.add(Dense(units=5, activation='softmax'))   #輸出為5個分類
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                1952
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 256)               33024
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 46,693
# Trainable params: 46,693
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
fitmodel = model.fit(x=train_feature, y=train_label, validation_split=0.2, epochs=40, batch_size=20, verbose=2)
score = model.evaluate(x=test_feature, y=test_label, verbose=2)
print('\n測試資料準確率:', score[1])
# Out:
# Epoch 1/40
# 2170/2170 - 26s - loss: 1.0192 - accuracy: 0.5378 - val_loss: 0.7207 - val_accuracy: 0.6934 - 26s/epoch - 12ms/step
# Epoch 2/40
# 2170/2170 - 23s - loss: 0.8036 - accuracy: 0.6492 - val_loss: 0.6573 - val_accuracy: 0.7451 - 23s/epoch - 10ms/step
# Epoch 3/40
# 2170/2170 - 23s - loss: 0.7564 - accuracy: 0.6723 - val_loss: 0.6538 - val_accuracy: 0.7226 - 23s/epoch - 10ms/step
# Epoch 4/40
# 2170/2170 - 23s - loss: 0.7201 - accuracy: 0.6935 - val_loss: 0.6232 - val_accuracy: 0.7331 - 23s/epoch - 10ms/step
# Epoch 5/40
# 2170/2170 - 23s - loss: 0.6864 - accuracy: 0.7089 - val_loss: 0.5564 - val_accuracy: 0.7856 - 23s/epoch - 11ms/step
# Epoch 6/40
# 2170/2170 - 23s - loss: 0.7000 - accuracy: 0.7045 - val_loss: 0.5838 - val_accuracy: 0.7566 - 23s/epoch - 10ms/step
# Epoch 7/40
# 2170/2170 - 23s - loss: 0.6710 - accuracy: 0.7173 - val_loss: 0.5509 - val_accuracy: 0.7717 - 23s/epoch - 10ms/step
# Epoch 8/40
# 2170/2170 - 23s - loss: 0.6611 - accuracy: 0.7248 - val_loss: 0.5443 - val_accuracy: 0.7783 - 23s/epoch - 10ms/step
# Epoch 9/40
# 2170/2170 - 23s - loss: 0.6644 - accuracy: 0.7181 - val_loss: 0.5855 - val_accuracy: 0.7506 - 23s/epoch - 10ms/step
# Epoch 10/40
# 2170/2170 - 23s - loss: 0.6727 - accuracy: 0.7140 - val_loss: 0.5127 - val_accuracy: 0.7977 - 23s/epoch - 10ms/step
# Epoch 11/40
# 2170/2170 - 23s - loss: 0.6480 - accuracy: 0.7273 - val_loss: 0.5224 - val_accuracy: 0.7757 - 23s/epoch - 10ms/step
# Epoch 12/40
# 2170/2170 - 23s - loss: 0.6398 - accuracy: 0.7313 - val_loss: 0.5447 - val_accuracy: 0.7750 - 23s/epoch - 11ms/step
# Epoch 13/40
# 2170/2170 - 24s - loss: 0.6299 - accuracy: 0.7371 - val_loss: 0.5039 - val_accuracy: 0.8015 - 24s/epoch - 11ms/step
# Epoch 14/40
# 2170/2170 - 23s - loss: 0.6519 - accuracy: 0.7274 - val_loss: 0.5357 - val_accuracy: 0.7690 - 23s/epoch - 11ms/step
# Epoch 15/40
# 2170/2170 - 22s - loss: 0.6147 - accuracy: 0.7459 - val_loss: 0.4832 - val_accuracy: 0.7984 - 22s/epoch - 10ms/step
# Epoch 16/40
# 2170/2170 - 23s - loss: 0.6003 - accuracy: 0.7516 - val_loss: 0.4255 - val_accuracy: 0.8383 - 23s/epoch - 11ms/step
# Epoch 17/40
# 2170/2170 - 17s - loss: 0.6006 - accuracy: 0.7519 - val_loss: 0.5301 - val_accuracy: 0.7823 - 17s/epoch - 8ms/step
# Epoch 18/40
# 2170/2170 - 17s - loss: 0.5862 - accuracy: 0.7592 - val_loss: 0.4912 - val_accuracy: 0.7968 - 17s/epoch - 8ms/step
# Epoch 19/40
# 2170/2170 - 21s - loss: 0.5746 - accuracy: 0.7637 - val_loss: 0.5513 - val_accuracy: 0.7588 - 21s/epoch - 10ms/step
# Epoch 20/40
# 2170/2170 - 17s - loss: 0.5673 - accuracy: 0.7685 - val_loss: 0.4969 - val_accuracy: 0.7906 - 17s/epoch - 8ms/step
# Epoch 21/40
# 2170/2170 - 17s - loss: 0.5990 - accuracy: 0.7509 - val_loss: 0.5406 - val_accuracy: 0.7648 - 17s/epoch - 8ms/step
# Epoch 22/40
# 2170/2170 - 17s - loss: 0.6031 - accuracy: 0.7466 - val_loss: 0.4782 - val_accuracy: 0.7995 - 17s/epoch - 8ms/step
# Epoch 23/40
# 2170/2170 - 17s - loss: 0.5984 - accuracy: 0.7480 - val_loss: 0.5557 - val_accuracy: 0.7736 - 17s/epoch - 8ms/step
# Epoch 24/40
# 2170/2170 - 16s - loss: 0.5968 - accuracy: 0.7517 - val_loss: 0.5144 - val_accuracy: 0.7970 - 16s/epoch - 8ms/step
# Epoch 25/40
# 2170/2170 - 16s - loss: 0.5801 - accuracy: 0.7602 - val_loss: 0.4792 - val_accuracy: 0.8104 - 16s/epoch - 8ms/step
# Epoch 26/40
# 2170/2170 - 16s - loss: 0.5745 - accuracy: 0.7646 - val_loss: 0.4679 - val_accuracy: 0.8170 - 16s/epoch - 8ms/step
# Epoch 27/40
# 2170/2170 - 16s - loss: 0.6022 - accuracy: 0.7525 - val_loss: 0.6061 - val_accuracy: 0.7526 - 16s/epoch - 8ms/step
# Epoch 28/40
# 2170/2170 - 16s - loss: 0.6109 - accuracy: 0.7458 - val_loss: 0.5117 - val_accuracy: 0.7842 - 16s/epoch - 8ms/step
# Epoch 29/40
# 2170/2170 - 16s - loss: 0.5869 - accuracy: 0.7564 - val_loss: 0.4952 - val_accuracy: 0.7908 - 16s/epoch - 8ms/step
# Epoch 30/40
# 2170/2170 - 16s - loss: 0.5896 - accuracy: 0.7570 - val_loss: 0.5785 - val_accuracy: 0.7640 - 16s/epoch - 8ms/step
# Epoch 31/40
# 2170/2170 - 16s - loss: 0.5891 - accuracy: 0.7572 - val_loss: 0.4678 - val_accuracy: 0.8126 - 16s/epoch - 8ms/step
# Epoch 32/40
# 2170/2170 - 16s - loss: 0.5826 - accuracy: 0.7611 - val_loss: 0.5222 - val_accuracy: 0.7833 - 16s/epoch - 8ms/step
# Epoch 33/40
# 2170/2170 - 16s - loss: 0.5757 - accuracy: 0.7664 - val_loss: 0.4735 - val_accuracy: 0.8022 - 16s/epoch - 8ms/step
# Epoch 34/40
# 2170/2170 - 16s - loss: 0.5660 - accuracy: 0.7689 - val_loss: 0.5765 - val_accuracy: 0.7371 - 16s/epoch - 8ms/step
# Epoch 35/40
# 2170/2170 - 17s - loss: 0.5679 - accuracy: 0.7680 - val_loss: 0.5556 - val_accuracy: 0.7674 - 17s/epoch - 8ms/step
# Epoch 36/40
# 2170/2170 - 16s - loss: 0.5659 - accuracy: 0.7681 - val_loss: 0.5403 - val_accuracy: 0.7792 - 16s/epoch - 8ms/step
# Epoch 37/40
# 2170/2170 - 16s - loss: 0.5610 - accuracy: 0.7723 - val_loss: 0.5566 - val_accuracy: 0.7674 - 16s/epoch - 8ms/step
# Epoch 38/40
# 2170/2170 - 16s - loss: 0.5621 - accuracy: 0.7725 - val_loss: 0.5057 - val_accuracy: 0.7799 - 16s/epoch - 8ms/step
# Epoch 39/40
# 2170/2170 - 16s - loss: 0.5496 - accuracy: 0.7789 - val_loss: 0.5436 - val_accuracy: 0.7586 - 16s/epoch - 8ms/step
# Epoch 40/40
# 2170/2170 - 16s - loss: 0.5493 - accuracy: 0.7775 - val_loss: 0.4434 - val_accuracy: 0.8212 - 16s/epoch - 8ms/step
# 424/424 - 2s - loss: 0.4548 - accuracy: 0.8183 - 2s/epoch - 4ms/step
#
# 測試資料準確率: 0.8183025121688843

# %%
model.save('DNN_origin_1.h5')
